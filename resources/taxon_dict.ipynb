# %% [markdown]
# ### <span style="color:teal"> __TAXONOMY DICTIONARY MAPPING__
# ____

# %%
# Loading packages
import pandas as pd
import numpy as np
import json
import requests
import time
from tqdm import tqdm

# %%
# Load the main dataset (GMRepo 'species_abundance.txt')
df = pd.read_csv("/mnt/iusers01/fatpou01/bmh01/msc-bioinf-2024-2025/h44063jg/gm_repository/species_abundance.txt", sep = '\t')

# %% [markdown]
# __TAXONOMY DICTIONARY__
# ____

# %%
taxon_id = df['ncbi_taxon_id'].unique()

# %%
#get update taxonomy species ID from NCBI or uniprot

API_KEY = "87fdd45a6ee743fecdbd1b7e9f010d669109"
BATCH_SIZE = 200

# Ensure your taxon_id list exists and convert to strings
taxon_id = [str(x) for x in taxon_id]

# Final dictionary and counters
taxon_dict = {}
from_ncbi = 0
from_uniprot = 0
unresolved = 0

def fetch_ncbi_batch(batch_ids):
    """Query NCBI for names (species preferred, fallback to higher rank)."""
    url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi"
    params = {
        'db': 'taxonomy',
        'id': ",".join(batch_ids),
        'retmode': 'json',
        'api_key': API_KEY
    }
    species = {}
    fallback = {}
    try:
        r = requests.get(url, params=params, timeout=15)
        if r.status_code == 200:
            result = r.json().get("result", {})
            for tid in batch_ids:
                record = result.get(tid, {})
                name = record.get("scientificname")
                rank = record.get("rank", "")
                if name:
                    if rank == "species":
                        species[tid] = name
                    else:
                        fallback[tid] = name
    except Exception as e:
        print(f" NCBI error for {batch_ids[:3]}: {e}")
    return species, fallback

def get_name_from_uniprot(tax_id):
    """Query UniProt as fallback."""
    url = f"https://rest.uniprot.org/taxonomy/{tax_id}"
    try:
        r = requests.get(url, timeout=10)
        if r.status_code == 200:
            return r.json().get("scientificName")
    except Exception as e:
        print(f" UniProt error for {tax_id}: {e}")
    return None

# Step 1: Query NCBI
missing_ids = []
for i in tqdm(range(0, len(taxon_id), BATCH_SIZE), desc="NCBI Batch lookup"):
    batch = taxon_id[i:i+BATCH_SIZE]
    species_dict, fallback_dict = fetch_ncbi_batch(batch)

    for tid in batch:
        tid_int = int(tid)
        if tid in species_dict:
            taxon_dict[tid_int] = species_dict[tid]
            from_ncbi += 1
        elif tid in fallback_dict:
            taxon_dict[tid_int] = fallback_dict[tid]
            from_ncbi += 1
        else:
            missing_ids.append(tid)

    time.sleep(0.4)  # NCBI rate limit

# Step 2: Query UniProt
for tid in tqdm(missing_ids, desc="UniProt fallback"):
    name = get_name_from_uniprot(tid)
    tid_int = int(tid)
    if name:
        taxon_dict[tid_int] = name
        from_uniprot += 1
    else:
        taxon_dict[tid_int] = "Unknown"
        unresolved += 1

# Step 3: Save the complete dictionary
with open("taxon_dict.json", "w") as f:
    json.dump({str(k): v for k, v in taxon_dict.items()}, f, indent=2)

# Step 4: Report summary
print("\n✅ Taxonomic Name Resolution Summary")
print("------------------------------------")
print(f"🔹 Total Taxon IDs Provided     : {len(taxon_id)}")
print(f"🔹 Resolved from NCBI           : {from_ncbi}")
print(f"🔹 Resolved from UniProt        : {from_uniprot}")
print(f"🔹 Unresolved IDs               : {unresolved}")
print(f"🔹 Final Entries in Dictionary  : {len(taxon_dict)}")


# Save final dictionary
with open("/mnt/iusers01/fatpou01/bmh01/msc-bioinf-2024-2025/h44063jg/gut_microbiome_project1/resources/taxon_dict.json", "w") as f:
    json.dump({str(k): v for k, v in taxon_dict.items()}, f, indent=2)

print("\n💾 Files saved:")
print(" - taxon_dict.json")
# Out:
# NCBI Batch lookup: 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# UniProt fallback: 100%|██████████| 86/86 [00:40<00:00,  2.14it/s]
# ✅ Taxonomic Name Resolution Summary
# ------------------------------------
# 🔹 Total Taxon IDs Provided     : 8910
# 🔹 Resolved from NCBI           : 8824
# 🔹 Resolved from UniProt        : 85
# 🔹 Unresolved IDs               : 1
# 🔹 Final Entries in Dictionary  : 8910
#
# 💾 Files saved:
#  - taxon_dict.json

# %%
taxon_dict
# Out:
# {1678: 'Bifidobacterium',
#  561: 'Escherichia',
#  816: 'Bacteroides',
#  1301: 'Streptococcus',
#  1279: 'Staphylococcus',
#  375288: 'Parabacteroides',
#  32207: 'Rothia',
#  102106: 'Collinsella',
#  1378: 'Gemella',
#  572511: 'Blautia',
#  53335: 'Pantoea',
#  40544: 'Sutterella',
#  292632: 'Subdoligranulum',
#  216816: 'Bifidobacterium longum',
#  1681: 'Bifidobacterium bifidum',
#  562: 'Escherichia coli',
#  1680: 'Bifidobacterium adolescentis',
#  1304: 'Streptococcus salivarius',
#  821: 'Phocaeicola vulgatus',
#  1282: 'Staphylococcus epidermidis',
#  820: 'Bacteroides uniformis',
#  43675: 'Rothia mucilaginosa',
#  1290: 'Staphylococcus hominis',
#  74426: 'Collinsella aerofaciens',
#  47678: 'Bacteroides caccae',
#  823: 'Parabacteroides distasonis',
#  28037: 'Streptococcus mitis',
#  1379: 'Gemella haemolysans',
#  1280: 'Staphylococcus aureus',
#  357276: 'Phocaeicola dorei',
#  28116: 'Bacteroides ovatus',
#  33038: 'Mediterraneibacter gnavus',
#  46506: 'Bacteroides stercoris',
#  204516: 'Phocaeicola massiliensis',
#  818: 'Bacteroides thetaiotaomicron',
#  40545: 'Sutterella wadsworthensis',
#  68892: 'Streptococcus infantis',
#  1685: 'Bifidobacterium breve',
#  1318: 'Streptococcus parasanguinis',
#  1308: 'Streptococcus thermophilus',
#  838: 'Prevotella',
#  1730: 'Eubacterium',
#  33024: 'Phascolarctobacterium',
#  33042: 'Coprococcus',
#  216851: 'Faecalibacterium',
#  239759: 'Alistipes',
#  1485: 'Clostridium',
#  1263: 'Ruminococcus',
#  841: 'Roseburia',
#  189330: 'Dorea',
#  544: 'Citrobacter',
#  397864: 'Barnesiella',
#  283168: 'Odoribacter',
#  35832: 'Bilophila',
#  872: 'Desulfovibrio',
#  244127: 'Anaerotruncus',
#  459786: 'Oscillibacter',
#  1348911: 'Coprobacter',
#  207244: 'Anaerostipes',
#  239934: 'Akkermansia',
#  830: 'Butyrivibrio',
#  61170: 'Holdemania',
#  135858: 'Catenibacterium',
#  447020: 'Adlercreutzia',
#  52225: 'Mitsuokella',
#  940557: 'Granulicella',
#  724: 'Haemophilus',
#  29465: 'Veillonella',
#  160674: 'Raoultella',
#  1017280: 'Pseudoflavonifractor',
#  165179: 'Segatella copri',
#  39485: 'Lachnospira eligens',
#  387090: 'Phocaeicola coprophilus',
#  626940: 'Phascolarctobacterium succinatutens',
#  46503: 'Parabacteroides merdae',
#  853: 'Faecalibacterium prausnitzii',
#  751585: 'Coprococcus sp. ART55/1',
#  28117: 'Alistipes putredinis',
#  665950: 'Lachnospiraceae bacterium 3_1_46FAA',
#  39491: 'Agathobacter rectalis',
#  411489: 'Clostridium sp. L2-50',
#  674529: 'Bacteroides faecis',
#  546: 'Citrobacter freundii',
#  665951: 'Lachnospiraceae bacterium 8_1_57FAA',
#  487174: 'Barnesiella intestinihominis',
#  88431: 'Dorea longicatena',
#  40518: 'Ruminococcus bromii',
#  28118: 'Odoribacter splanchnicus',
#  1118061: 'Alistipes obesi',
#  40519: 'Ruminococcus callidus',
#  360807: 'Roseburia inulinivorans',
#  166486: 'Roseburia intestinalis',
#  40520: 'Blautia obeum',
#  33039: '[Ruminococcus] torques',
#  1735: 'Holdemanella biformis',
#  46228: '[Ruminococcus] lactaris',
#  371601: 'Bacteroides xylanisolvens',
#  338188: 'Bacteroides finegoldii',
#  901: 'Desulfovibrio piger',
#  39486: 'Dorea formicigenerans',
#  328814: 'Alistipes shahii',
#  39488: 'Anaerobutyricum hallii',
#  410072: 'Coprococcus comes',
#  1211813: 'Alistipes ihumii AP11',
#  39496: 'Eubacterium ventriosum',
#  116085: 'Coprococcus catus',
#  658087: 'Lachnospiraceae bacterium 7_1_58FAA',
#  658089: 'Lachnospiraceae bacterium 5_1_63FAA',
#  1099853: 'Coprobacter fastidiosus',
#  301301: 'Roseburia hominis',
#  649756: 'Anaerostipes hadrus',
#  39490: 'Eubacterium ramulus',
#  39492: '[Eubacterium] siraeum',
#  239935: 'Akkermansia muciniphila',
#  35833: 'Bilophila wadsworthia',
#  1264: 'Ruminococcus albus',
#  61171: 'Holdemania filiformis',
#  1288121: 'Alistipes senegalensis',
#  100886: 'Catenibacterium mitsuokai',
#  446660: 'Adlercreutzia equolifaciens',
#  658081: 'Lachnospiraceae bacterium 1_1_57FAA',
#  261299: 'Intestinibacter bartlettii',
#  33043: 'Coprococcus eutactus',
#  1265: 'Ruminococcus flavefaciens',
#  876: 'Desulfovibrio desulfuricans',
#  729: 'Haemophilus parainfluenzae',
#  328813: 'Alistipes onderdonkii',
#  214851: 'Subdoligranulum variabile',
#  552398: 'Ruminococcaceae bacterium D16',
#  29347: '[Clostridium] scindens',
#  333367: 'Enterocloster asparagiformis',
#  54291: 'Raoultella ornithinolytica',
#  106588: 'Pseudoflavonifractor capillosus',
#  658082: 'Lachnospiraceae bacterium 2_1_58FAA',
#  28111: 'Bacteroides eggerthii',
#  906: 'Megasphaera',
#  283: 'Comamonas',
#  836: 'Porphyromonas',
#  1578: 'Lactobacillus',
#  117563: 'Granulicatella',
#  84111: 'Eggerthella',
#  1654: 'Actinomyces',
#  150022: 'Finegoldia',
#  194: 'Campylobacter',
#  946234: 'Flavonifractor',
#  1357: 'Lactococcus',
#  133925: 'Olsenella',
#  577310: 'Parasutterella',
#  1350: 'Enterococcus',
#  162289: 'Peptoniphilus',
#  1380: 'Atopobium',
#  184869: 'Varibaculum',
#  907: 'Megasphaera elsdenii',
#  1226323: 'Oscillibacter sp. KLE 1745',
#  457412: 'Ruminococcus sp. 5_1_39BFAA',
#  310297: 'Phocaeicola plebeius',
#  246787: 'Bacteroides cellulosilyticus',
#  285: 'Comamonas testosteroni',
#  1535: '[Clostridium] leptum',
#  626932: 'Alistipes indistinctus',
#  28123: 'Porphyromonas asaccharolytica',
#  322095: 'Porphyromonas somerae',
#  29466: 'Veillonella parvula',
#  214856: 'Alistipes finegoldii',
#  1623: 'Ligilactobacillus ruminis',
#  501496: 'Porphyromonas bennonis',
#  1582: 'Lacticaseibacillus casei',
#  131111: 'Schaalia turicensis',
#  28127: 'Hoylesella buccalis',
#  1260: 'Finegoldia magna',
#  76517: 'Campylobacter hominis',
#  292800: 'Flavonifractor plautii',
#  84112: 'Eggerthella lenta',
#  1358: 'Lactococcus lactis',
#  386414: 'Hoylesella timonensis',
#  208479: 'Enterocloster bolteae',
#  457421: 'Clostridiales bacterium 1_7_47FAA',
#  487175: 'Parasutterella excrementihominis',
#  154046: 'Hungatella hathewayi',
#  113107: 'Streptococcus australis',
#  658657: 'Erysipelotrichaceae bacterium 21_3',
#  39778: 'Veillonella dispar',
#  1343: 'Streptococcus vestibularis',
#  46124: 'Granulicatella adiacens',
#  469610: 'Burkholderiales bacterium 1_1_47',
#  1689: 'Bifidobacterium dentium',
#  169435: 'Anaerotruncus colihominis',
#  817: 'Bacteroides fragilis',
#  1351: 'Enterococcus faecalis',
#  1302: 'Streptococcus gordonii',
#  358743: 'Enterocloster citroniae',
#  457422: 'Erysipelotrichaceae bacterium 2_2_44A',
#  827: 'Campylobacter ureolyticus',
#  33031: 'Peptoniphilus lacrimalis',
#  1305: 'Streptococcus sanguinis',
#  84135: 'Gemella sanguinis',
#  1382: 'Lancefieldella parvula',
#  184870: 'Varibaculum cambriense',
#  1660: 'Schaalia odontolytica',
#  2172: 'Methanobrevibacter',
#  39948: 'Dialister',
#  577309: 'Paraprevotella',
#  84567: 'Pedobacter',
#  191303: 'Turicibacter',
#  644652: 'Gordonibacter',
#  39483: 'Faecalitalea cylindroides',
#  2173: 'Methanobrevibacter smithii',
#  310298: 'Phocaeicola coprocola',
#  218538: 'Dialister invisus',
#  387661: 'Parabacteroides johnsonii',
#  626929: 'Bacteroides clarus',
#  1522: '[Clostridium] innocuum',
#  454154: 'Paraprevotella clara',
#  1352: 'Enterococcus faecium',
#  471189: 'Gordonibacter pamelaeae',
#  291645: 'Bacteroides nordii',
#  28025: 'Bifidobacterium animalis',
#  1512: '[Clostridium] symbiosum',
#  2316: 'Methanosphaera',
#  45851: 'Eshraghiella crossota',
#  329854: 'Bacteroides intestinalis',
#  2317: 'Methanosphaera stadtmanae',
#  454155: 'Paraprevotella xylaniphila',
#  165779: 'Anaerococcus',
#  1696: 'Brevibacterium',
#  1716: 'Corynebacterium',
#  1502: 'Clostridium perfringens',
#  1505: 'Paraclostridium sordellii',
#  1328: 'Streptococcus anginosus',
#  1077464: 'Streptococcus oralis subsp. tigurinus',
#  33034: 'Anaerococcus prevotii',
#  1334: 'Streptococcus dysgalactiae',
#  1633: 'Limosilactobacillus vaginalis',
#  147802: 'Lactobacillus iners',
#  43765: 'Corynebacterium amycolatum',
#  38304: 'Corynebacterium tuberculostearicum',
#  713: 'Actinobacillus',
#  104264: 'Cellulophaga',
#  846: 'Oxalobacter',
#  416916: 'Aggregatibacter',
#  1078480: 'Haemophilus sputorum',
#  1683: 'Bifidobacterium angulatum',
#  328812: 'Parabacteroides goldsteinii',
#  291644: 'Bacteroides salyersiae',
#  847: 'Oxalobacter formigenes',
#  154288: 'Turicibacter sanguinis',
#  1584: 'Lactobacillus delbrueckii',
#  726: 'Haemophilus haemolyticus',
#  100883: 'Coprobacillus',
#  158846: 'Megamonas',
#  248744: 'Marvinbryantia',
#  908612: 'Alistipes sp. HGB5',
#  457402: 'Eubacterium sp. 3_1_31',
#  552396: 'Erysipelotrichaceae bacterium 5_2_54FAA',
#  168384: 'Marvinbryantia formatexigens',
#  1547: 'Thomasclavelia ramosa',
#  84108: 'Slackia',
#  1298: 'Deinococcus',
#  574697: 'Butyricimonas',
#  626934: 'Slackia piriformis',
#  197614: 'Streptococcus pasteurianus',
#  544644: 'Butyricimonas synergistica',
#  137732: 'Granulicatella elegans',
#  626931: 'Bacteroides oleiciplenus',
#  848: 'Fusobacterium',
#  469591: 'Parabacteroides sp. 20_3',
#  28026: 'Bifidobacterium pseudocatenulatum',
#  658655: 'Lachnospiraceae bacterium 1_4_56FAA',
#  1070699: 'Clostridiaceae bacterium JC118',
#  849: 'Fusobacterium gonidiaformans',
#  39777: 'Veillonella atypica',
#  469614: 'Erysipelotrichaceae bacterium 6_1_45',
#  658086: 'Lachnospiraceae bacterium 3_1_57FAA_CT1',
#  1118060: 'Enorma massiliensis phI',
#  1531: 'Enterocloster clostridioformis',
#  53443: 'Blautia hydrogenotrophica',
#  583: 'Proteus',
#  46255: 'Weissella',
#  904: 'Acidaminococcus',
#  29361: '[Clostridium] nexile',
#  742723: 'Lachnospiraceae bacterium 2_1_46FAA',
#  626935: 'Collinsella tanakaei',
#  137591: 'Weissella cibaria',
#  187327: 'Acidaminococcus intestini',
#  658085: 'Lachnospiraceae bacterium 5_1_57FAA',
#  28125: 'Prevotella bivia',
#  658088: 'Lachnospiraceae bacterium 9_1_43BFAA',
#  1257: 'Peptostreptococcus',
#  658659: 'Erysipelotrichaceae bacterium 3_1_53',
#  33037: 'Anaerococcus vaginalis',
#  1287640: 'Anaerococcus obesiensis',
#  859: 'Fusobacterium necrophorum',
#  33035: 'Blautia producta',
#  1261: 'Peptostreptococcus anaerobius',
#  487173: 'Dialister succinatiphilus',
#  69965: 'Macrococcus',
#  1496: 'Clostridioides difficile',
#  105841: 'Anaerostipes caccae',
#  37734: 'Enterococcus casseliflavus',
#  33945: 'Enterococcus avium',
#  658083: 'Lachnospiraceae bacterium 6_1_63FAA',
#  1721: 'Corynebacterium callunae',
#  69966: 'Macrococcoides caseolyticum',
#  547: 'Enterobacter',
#  384638: '[Bacteroides] pectinophilus',
#  905: 'Acidaminococcus fermentans',
#  550: 'Enterobacter cloacae',
#  1161942: 'Ruminococcus champanellensis',
#  1253: 'Pediococcus',
#  1583: 'Weissella confusa',
#  1624: 'Ligilactobacillus salivarius',
#  1255: 'Pediococcus pentosaceus',
#  1598: 'Limosilactobacillus reuteri',
#  1613: 'Limosilactobacillus fermentum',
#  1599: 'Latilactobacillus sakei',
#  1033: 'Afipia',
#  56946: 'Afipia broomeae',
#  1590: 'Lactiplantibacillus plantarum',
#  1243: 'Leuconostoc',
#  1743: 'Propionibacterium',
#  1226325: 'Clostridium sp. KLE 1755',
#  1736: 'Eubacterium limosum',
#  1245: 'Leuconostoc mesenteroides',
#  341694: 'Peptostreptococcus stomatis',
#  1744: 'Propionibacterium freudenreichii',
#  84109: 'Slackia exigua',
#  55565: 'Actinomyces graevenitzii',
#  123375: 'Solobacterium',
#  103892: 'Veillonella ratti',
#  102148: 'Solobacterium moorei',
#  1309: 'Streptococcus mutans',
#  482: 'Neisseria',
#  265975: 'Oribacterium',
#  196082: 'Parascardovia',
#  1213720: 'Stomatobaculum',
#  196081: 'Scardovia',
#  47670: 'Lautropia',
#  543311: 'Parvimonas',
#  156454: 'Anaeroglobus',
#  1686: 'Bifidobacterium catenulatum',
#  97478: 'Limosilactobacillus mucosae',
#  47770: 'Lactobacillus crispatus',
#  187326: 'Megasphaera micronuciformis',
#  649724: 'Clostridium sp. ATCC BAA-442',
#  484: 'Neisseria flavescens',
#  237576: 'Oribacterium sinus',
#  78258: 'Parascardovia denticolens',
#  736: 'Haemophilus paraphrohaemolyticus',
#  495: 'Neisseria elongata',
#  28449: 'Neisseria subflava',
#  199: 'Campylobacter concisus',
#  936594: 'Lachnoanaerobaculum sp. ICM7',
#  796942: 'Stomatobaculum longum',
#  739: 'Aggregatibacter segnis',
#  1383: 'Lancefieldella rimae',
#  712976: 'Lachnospiraceae bacterium oral taxon 082',
#  860: 'Fusobacterium periodonticum',
#  727: 'Haemophilus influenzae',
#  851: 'Fusobacterium nucleatum',
#  490: 'Neisseria sicca',
#  552395: 'Lachnospiraceae bacterium 4_1_37FAA',
#  47671: 'Lautropia mirabilis',
#  1632: 'Limosilactobacillus oris',
#  150055: 'Streptococcus lutetiensis',
#  735: 'Haemophilus parahaemolyticus',
#  496: 'Neisseria macacae',
#  487: 'Neisseria meningitidis',
#  861: 'Fusobacterium ulcerans',
#  59310: 'Streptococcus macedonicus',
#  2047: 'Rothia dentocariosa',
#  156456: 'Anaeroglobus geminatus',
#  66831: 'Facklamia',
#  570: 'Klebsiella',
#  754330: 'Escherichia sp. TW09276',
#  281920: 'Porphyromonas uenonis',
#  571: 'Klebsiella oxytoca',
#  1335745: 'Spiribacter',
#  620: 'Shigella',
#  469596: 'Coprobacillus sp. 29_1',
#  623: 'Shigella flexneri',
#  29521: 'Brachyspira',
#  573: 'Klebsiella pneumoniae',
#  149698: 'Massilia',
#  29348: 'Thomasclavelia spiroformis',
#  665956: 'Subdoligranulum sp. 4_3_54A2FAA',
#  31971: 'Amedibacillus dolichus',
#  56774: '[Eubacterium] infirmum',
#  33964: 'Leuconostoc citreum',
#  2701: 'Gardnerella',
#  2702: 'Gardnerella vaginalis',
#  68891: 'Streptococcus peroris',
#  54005: 'Peptoniphilus harei',
#  43769: 'Corynebacterium propinquum',
#  1311: 'Streptococcus agalactiae',
#  82135: 'Fannyhessea vaginae',
#  580596: 'Butyricicoccus',
#  209: 'Helicobacter',
#  147207: 'Collinsella intestinalis',
#  437897: 'Megamonas funiformis',
#  850: 'Fusobacterium mortiferum',
#  158847: 'Megamonas hypermegale',
#  665937: 'Anaerostipes sp. 3_2_56FAA',
#  501571: 'Butyricicoccus pullicaecorum',
#  491921: 'Megamonas rupellensis',
#  37372: 'Helicobacter bilis',
#  33968: 'Leuconostoc pseudomesenteroides',
#  457392: 'Bacteroides sp. 3_2_5',
#  856: 'Fusobacterium varium',
#  626933: 'Odoribacter laneus',
#  556262: 'Coprobacillus sp. D6',
#  29391: 'Gemella morbillorum',
#  1604: 'Lactobacillus amylovorus',
#  33033: 'Parvimonas micra',
#  156973: 'Dysgonomonas',
#  102684: 'Streptococcus infantarius',
#  1211819: 'Holdemania massiliensis AP2',
#  84026: '[Clostridium] methylpentosum',
#  469: 'Acinetobacter',
#  40323: 'Stenotrophomonas',
#  469588: 'Bacteroides sp. 2_1_22',
#  246144: 'Enterococcus italicus',
#  1246: 'Leuconostoc lactis',
#  106649: 'Acinetobacter guillouiae',
#  40324: 'Stenotrophomonas maltophilia',
#  246432: 'Staphylococcus equorum',
#  1283313: 'Alloprevotella',
#  538: 'Eikenella',
#  1164882: 'Lachnoanaerobaculum',
#  309120: 'Dialister micraerophilus',
#  76860: 'Streptococcus constellatus',
#  76122: 'Alloprevotella tannerae',
#  28130: 'Prevotella disiens',
#  539: 'Eikenella corrodens',
#  467210: 'Lachnoanaerobaculum saburreum',
#  1226322: 'Oscillibacter sp. KLE 1728',
#  1596: 'Lactobacillus gasseri',
#  230143: 'Scardovia wiggsiae',
#  363265: 'Leyella stercorea',
#  437898: 'Sutterella parvirubra',
#  53345: 'Enterococcus durans',
#  1322: 'Blautia hansenii',
#  1105031: 'Clostridium sp. MSTE9',
#  47715: 'Lacticaseibacillus rhamnosus',
#  133926: 'Olsenella uli',
#  33029: 'Anaerococcus hydrogenalis',
#  1073: 'Rhodopseudomonas',
#  1747: 'Cutibacterium acnes',
#  1656: 'Actinomyces viscosus',
#  461393: 'Actinomyces massiliensis',
#  52226: 'Mitsuokella multacida',
#  76833: 'Actinobaculum',
#  103621: 'Actinomyces urogenitalis',
#  59505: 'Actinotignum schaalii',
#  674963: 'Succinatimonas',
#  626938: 'Succinatimonas hippei',
#  548: 'Klebsiella aerogenes',
#  28035: 'Staphylococcus lugdunensis',
#  671229: 'Veillonella sp. oral taxon 780',
#  1283: 'Staphylococcus haemolyticus',
#  29380: 'Staphylococcus caprae',
#  483: 'Neisseria cinerea',
#  1625: 'Fructilactobacillus sanfranciscensis',
#  45634: 'Streptococcus cristatus',
#  257758: 'Streptococcus pseudopneumoniae',
#  624: 'Shigella sonnei',
#  457394: 'Bacteroides sp. 4_3_47FAA',
#  469592: 'Bacteroides sp. 3_1_19',
#  194326: 'Companilactobacillus versmoldensis',
#  38303: 'Corynebacterium pseudogenitalium',
#  457387: 'Bacteroides sp. 1_1_30',
#  248038: 'Mucispirillum',
#  2745: 'Halomonas',
#  248039: 'Mucispirillum schaedleri',
#  581: 'Morganella',
#  32008: 'Burkholderia',
#  517: 'Bordetella',
#  582: 'Morganella morganii',
#  46123: 'Abiotrophia',
#  69218: 'Enterobacter cancerogenus',
#  46125: 'Abiotrophia defectiva',
#  586: 'Providencia',
#  84162: 'Cryptobacterium',
#  28126: 'Segatella buccae',
#  457396: 'Clostridium sp. 7_2_43FAA',
#  66219: 'Lachnoclostridium phytofermentans',
#  1353: 'Enterococcus gallinarum',
#  84163: 'Cryptobacterium curtum',
#  126385: 'Providencia alcalifaciens',
#  68335: 'Coprothermobacter',
#  46613: 'Anaerobaculum',
#  2222: 'Methanothrix',
#  1279384: 'Eggerthia',
#  35786: 'Coprothermobacter proteolyticus',
#  97477: 'Acetomicrobium mobile',
#  2224: 'Methanothrix thermoacetophila',
#  31973: 'Eggerthia catenaformis',
#  638847: 'Pyramidobacter',
#  638849: 'Pyramidobacter piscolens',
#  203133: 'Propionimicrobium',
#  1509: 'Clostridium sporogenes',
#  665943: 'Eggerthella sp. 1_3_56FAA',
#  33012: 'Propionimicrobium lymphophilum',
#  2753: 'Synergistes',
#  457415: 'Synergistes sp. 3_1_syn1',
#  698776: 'Cellulosilyticum',
#  29360: 'Cellulosilyticum lentocellum',
#  908340: 'Clostridium sp. HGF2',
#  242750: 'Hallella bergensis',
#  1254: 'Pediococcus acidilactici',
#  33010: 'Cutibacterium avidum',
#  970: 'Selenomonas',
#  36834: 'Clostridium celatum',
#  416586: 'Selenomonas bovis',
#  376804: 'Phocaeicola barnesiae',
#  626930: 'Bacteroides fluxus',
#  286: 'Pseudomonas',
#  264995: 'Anaerofustis',
#  1579: 'Lactobacillus acidophilus',
#  1244: 'Leuconostoc gelidum',
#  296: 'Pseudomonas fragi',
#  214853: 'Anaerofustis stercorihominis',
#  118747: 'Bulleidia',
#  118748: 'Bulleidia extructa',
#  89153: '[Clostridium] hylemonae',
#  204: 'Campylobacter showae',
#  1338: 'Streptococcus intermedius',
#  1580: 'Levilactobacillus brevis',
#  71452: 'Enterococcus raffinosus',
#  29393: 'Dolosigranulum',
#  435842: 'Streptococcus sp. C150',
#  29394: 'Dolosigranulum pigrum',
#  1105030: 'Actinomyces sp. ICM58',
#  66228: 'Gleimia europaea',
#  37637: 'Corynebacterium pseudodiphtheriticum',
#  38284: 'Corynebacterium accolens',
#  584: 'Proteus mirabilis',
#  33007: 'Winkia neuii',
#  507750: 'Peptoniphilus duerdenii',
#  244366: 'Klebsiella variicola',
#  469585: 'Bacteroides sp. 1_1_14',
#  102862: 'Proteus penneri',
#  33959: 'Lactobacillus johnsonii',
#  1292: 'Staphylococcus warneri',
#  45972: 'Staphylococcus pasteuri',
#  197: 'Campylobacter jejuni',
#  2093: 'Mycoplasma',
#  1492: 'Clostridium butyricum',
#  28903: 'Mycoplasmopsis bovis',
#  35517: '[Eubacterium] brachy',
#  36841: 'Terrisporobacter glycolicus',
#  249188: 'Haemophilus pittmaniae',
#  469613: 'Enterobacteriaceae bacterium 9_2_54FAA',
#  212791: 'Enhydrobacter',
#  106589: 'Cupriavidus',
#  225324: 'Enhydrobacter aerosaccus',
#  40215: 'Acinetobacter junii',
#  134533: 'Acinetobacter parvus',
#  195041: 'Streptococcus oligofermentans',
#  1750: 'Arachnia propionica',
#  652708: 'Bacteroidetes oral taxon 274',
#  749535: 'Klebsiella sp. MS 92-3',
#  1310: 'Streptococcus sobrinus',
#  564: 'Escherichia fergusonii',
#  1363: 'Lactococcus garvieae',
#  158836: 'Enterobacter hormaechei',
#  2050: 'Mobiluncus',
#  2051: 'Mobiluncus curtisii',
#  28038: 'Latilactobacillus curvatus',
#  545: 'Citrobacter koseri',
#  1091: 'Chlorobium',
#  40214: 'Acinetobacter johnsonii',
#  1096: 'Chlorobium phaeobacteroides',
#  1366: 'Pseudolactococcus raffinolactis',
#  149016: 'Streptococcus urinalis',
#  136609: 'Leuconostoc kimchii',
#  702: 'Plesiomonas',
#  703: 'Plesiomonas shigelloides',
#  156974: 'Dysgonomonas gadei',
#  1232426: '[Collinsella] massiliensis',
#  712430: 'Peptoniphilus sp. oral taxon 375',
#  33032: 'Anaerococcus lactolyticus',
#  200: 'Campylobacter curvus',
#  1249: 'Weissella paramesenteroides',
#  89152: 'Peptacetobacter hiranonis',
#  41978: 'Ruminococcus sp.',
#  163665: 'Dysgonomonas mossii',
#  1095771: 'Ruminococcus sp. JC304',
#  1252: 'Leuconostoc carnosum',
#  1655: 'Actinomyces naeslundii',
#  28453: 'Sphingobacterium',
#  57732: 'Enterococcus asini',
#  86331: 'Mogibacterium',
#  893: 'Desulfobulbus',
#  195950: 'Tannerella',
#  1016: 'Capnocytophaga',
#  157: 'Treponema',
#  1434006: 'Fretibacterium',
#  113286: 'Pseudoramibacter',
#  44259: 'Filifactor',
#  43996: 'Catonella',
#  32257: 'Kingella',
#  32067: 'Leptotrichia',
#  2717: 'Cardiobacterium',
#  43994: 'Johnsonella',
#  936375: 'Mogibacterium sp. CM50',
#  51123: '[Eubacterium] saphenum',
#  712258: 'Desulfobulbus sp. oral taxon 041',
#  28112: 'Tannerella forsythia',
#  706435: 'Capnocytophaga sp. oral taxon 329',
#  651822: 'Fretibacterium fastidiosum',
#  651591: 'Bacteroidetes bacterium oral taxon 272',
#  732: 'Aggregatibacter aphrophilus',
#  113287: 'Pseudoramibacter alactolyticus',
#  143361: 'Filifactor alocis',
#  1017: 'Capnocytophaga gingivalis',
#  53419: 'Treponema socranskii',
#  172042: 'Rothia aeria',
#  53418: 'Treponema lecithinolyticum',
#  203: 'Campylobacter rectus',
#  158: 'Treponema denticola',
#  1288391: 'Actinomyces timonensis',
#  840: 'Hoylesella loescheii',
#  43997: 'Catonella morbi',
#  51160: 'Treponema maltophilum',
#  39498: '[Eubacterium] yurii',
#  43768: 'Corynebacterium matruchotii',
#  837: 'Porphyromonas gingivalis',
#  544580: 'Actinomyces oris',
#  181487: 'Schaalia cardiffensis',
#  712991: 'Lachnospiraceae bacterium oral taxon 500',
#  633701: 'Hoylesella saccharolytica',
#  28124: 'Porphyromonas endodontalis',
#  502: 'Kingella denitrificans',
#  45242: 'Capnocytophaga granulosa',
#  407975: 'Hoylesella pleuritidis',
#  544581: 'Actinomyces johnsonii',
#  2718: 'Cardiobacterium hominis',
#  69823: 'Selenomonas sputigena',
#  138595: 'Olsenella profusa',
#  824: 'Campylobacter gracilis',
#  61592: 'Corynebacterium durum',
#  43995: 'Johnsonella ignava',
#  135083: 'Selenomonas noxia',
#  1018: 'Capnocytophaga ochracea',
#  28131: 'Prevotella intermedia',
#  194702: 'Cardiobacterium valvarum',
#  41976: 'Porphyromonas catoniae',
#  714: 'Aggregatibacter actinomycetemcomitans',
#  58231: 'Treponema medium',
#  267212: 'Neisseria bacilliformis',
#  652706: 'Oribacterium sp. oral taxon 078',
#  135082: 'Selenomonas infelix',
#  40542: 'Leptotrichia buccalis',
#  287: 'Pseudomonas aeruginosa',
#  613: 'Serratia',
#  615: 'Serratia marcescens',
#  178214: 'Facklamia hominis',
#  28132: 'Prevotella melaninogenica',
#  1203556: 'Actinomyces sp. HPA0247',
#  419014: 'Alloscardovia',
#  223527: 'Vreelandella boliviensis',
#  419015: 'Alloscardovia omnicolens',
#  35818: 'Helicobacter pullorum',
#  376805: 'Phocaeicola salanitronis',
#  28135: 'Segatella oris',
#  53246: 'Pseudoalteromonas',
#  228: 'Pseudoalteromonas haloplanktis',
#  43660: 'Pseudoalteromonas undina',
#  34084: 'Riemerella',
#  693988: 'Bilophila sp. 4_1_30',
#  563193: 'Parabacteroides sp. D13',
#  1612: 'Companilactobacillus farciminis',
#  32012: 'Thiomonas',
#  52768: 'Schaalia georgiae',
#  1381: 'Atopobium minutum',
#  588: 'Providencia stuartii',
#  568: 'Hafnia',
#  569: 'Hafnia alvei',
#  810: 'Chlamydia',
#  28134: 'Hoylesella oralis',
#  2260: 'Pyrococcus',
#  1314: 'Streptococcus pyogenes',
#  1008460: 'Pyrococcus yayanosii',
#  376806: 'Bacteroides gallinarum',
#  160453: 'Enterococcus gilvus',
#  1354: 'Enterococcus hirae',
#  165697: 'Sphingopyxis',
#  265: 'Paracoccus',
#  1839: 'Nocardioides',
#  29404: 'Microlunatus',
#  57493: 'Kocuria',
#  323620: 'Shinella',
#  165695: 'Sphingobium',
#  83618: 'Pseudoxanthomonas',
#  68287: 'Mesorhizobium',
#  41275: 'Brevundimonas',
#  110932: 'Leifsonia',
#  75: 'Caulobacter',
#  34072: 'Variovorax',
#  72173: 'Citromicrobium',
#  29405: 'Microlunatus phosphovorus',
#  352475: 'Shinella zoogloeoides',
#  266: 'Paracoccus denitrificans',
#  72000: 'Kocuria rhizophila',
#  147206: 'Collinsella stercoris',
#  61645: 'Enterobacter asburiae',
#  539813: 'Enterobacter mori',
#  189723: 'Prevotella micans',
#  796940: 'Peptostreptococcaceae bacterium CM5',
#  469586: 'Bacteroides sp. 1_1_6',
#  201096: 'Alicycliphilus',
#  796941: 'Peptostreptococcaceae bacterium OBRC8',
#  439703: 'Segatella maculosa',
#  340486: 'Prevotella conceptionensis',
#  485: 'Neisseria gonorrhoeae',
#  33011: 'Cutibacterium granulosum',
#  629: 'Yersinia',
#  630: 'Yersinia enterocolitica',
#  174708: 'Allobaculum',
#  174709: 'Allobaculum stercoricanis',
#  565: 'Atlantibacter hermannii',
#  773: 'Bartonella',
#  1386: 'Bacillus',
#  1396: 'Bacillus cereus',
#  28090: 'Acinetobacter lwoffii',
#  180162: 'Cetobacterium',
#  188913: 'Cetobacterium somerae',
#  450749: 'Veillonella sp. 6_1_27',
#  265488: 'Rhodopirellula',
#  161879: 'Corynebacterium kroppenstedtii',
#  84030: 'Lacrimispora saccharolytica',
#  228229: 'Ligilactobacillus saerimneri',
#  1203555: 'Acidaminococcus sp. HPA0509',
#  29385: 'Staphylococcus saprophyticus',
#  1490: 'Paraclostridium bifermentans',
#  109790: 'Lactobacillus jensenii',
#  33877: 'Agromyces',
#  55968: 'Leucobacter',
#  208962: 'Escherichia albertii',
#  80865: 'Delftia',
#  44009: 'Enterococcus dispar',
#  535: 'Chromobacterium',
#  1694: 'Bifidobacterium pseudolongum',
#  1587: 'Lactobacillus helveticus',
#  74385: 'Gracilibacillus',
#  1081: 'Rhodospirillum',
#  936548: 'Actinomyces sp. ICM47',
#  53346: 'Enterococcus mundtii',
#  59732: 'Chryseobacterium',
#  293: 'Brevundimonas diminuta',
#  487316: 'Acinetobacter soli',
#  80866: 'Delftia acidovorans',
#  671216: 'Peptoniphilus sp. oral taxon 836',
#  1111135: 'Coriobacteriaceae bacterium BV3Ac1',
#  169292: 'Corynebacterium aurimucosum',
#  38289: 'Corynebacterium jeikeium',
#  108981: 'Acinetobacter schindleri',
#  411484: 'Clostridium sp. SS2/1',
#  1581: 'Lentilactobacillus buchneri',
#  2098: 'Metamycoplasma hominis',
#  36739: 'Dermabacter',
#  1203568: 'Dermabacter sp. HFH0086',
#  1727: 'Corynebacterium variabile',
#  300: 'Ectopseudomonas mendocina',
#  160454: 'Enterococcus pallens',
#  28263: 'Arcanobacterium',
#  29580: 'Janthinobacterium',
#  28264: 'Arcanobacterium haemolyticum',
#  470565: 'Prevotella histicola',
#  43263: 'Aquipseudomonas alcaligenes',
#  665938: 'Bacteroides sp. 2_1_56FAA',
#  400634: 'Lysinibacillus',
#  28196: 'Arcobacter',
#  33057: 'Thauera',
#  1827: 'Rhodococcus',
#  76890: 'Asticcacaulis',
#  76831: 'Myroides',
#  378210: 'Methyloversatilis',
#  222: 'Achromobacter',
#  108980: 'Acinetobacter ursingii',
#  1421: 'Lysinibacillus sphaericus',
#  46680: 'Pseudomonas nitroreducens',
#  164400: 'Thauera phenylacetica',
#  316: 'Stutzerimonas stutzeri',
#  43306: 'Pseudomonas denitrificans (nom. rej.)',
#  1833: 'Rhodococcus erythropolis',
#  179636: 'Alicycliphilus denitrificans',
#  28197: 'Aliarcobacter butzleri',
#  75612: 'Pseudomonas mandelii',
#  72556: 'Achromobacter piechaudii',
#  65551: 'Meiothermus',
#  29330: 'Alicyclobacillus',
#  662: 'Vibrio',
#  52022: 'Allomeiothermus silvanus',
#  232270: 'Effusibacillus pohliae',
#  170673: 'Vibrio kanaloae',
#  392733: 'Terriglobus',
#  1589: 'Lactiplantibacillus pentosus',
#  1033744: 'Peptoniphilus senegalensis JC140',
#  1111134: 'Peptoniphilus sp. BV3C26',
#  2038: 'Tropheryma',
#  2039: 'Tropheryma whipplei',
#  40216: 'Acinetobacter radioresistens',
#  202789: 'Actinobaculum massiliense',
#  115778: 'Leuconostoc gasicomitatum',
#  48736: 'Ralstonia',
#  329: 'Ralstonia pickettii',
#  195: 'Campylobacter coli',
#  13690: 'Sphingobium yanoikuyae',
#  556261: 'Clostridium sp. D5',
#  661086: 'Olsenella sp. oral taxon 809',
#  315405: 'Streptococcus gallolyticus',
#  2737: 'Vagococcus',
#  999425: 'Streptococcus sp. F0442',
#  81947: 'Vagococcus lutrae',
#  563191: 'Acidaminococcus sp. D21',
#  580024: 'Enterorhabdus',
#  671266: 'Adlercreutzia caecimuris',
#  310514: 'Hallella multisaccharivorax',
#  910311: 'Eggerthella sp. HGA1',
#  28129: 'Prevotella denticola',
#  1076: 'Rhodopseudomonas palustris',
#  228604: 'Segatella salivae',
#  1111120: 'Acidaminococcus sp. BV3L6',
#  1348: 'Streptococcus parauberis',
#  28136: 'Segatella oulorum',
#  60133: 'Prevotella pallens',
#  671218: 'Alloprevotella rava',
#  476270: 'Pediococcus lolii',
#  1610: 'Loigolactobacillus coryniformis',
#  457416: 'Veillonella sp. 3_1_44',
#  420645: 'Lactobacillus equicursoris',
#  1288: 'Staphylococcus xylosus',
#  1203571: 'Propionibacterium sp. HGH0353',
#  71451: 'Enterococcus malodoratus',
#  227943: 'Limosilactobacillus antri',
#  1032506: 'Prevotella sp. MSX73',
#  413496: 'Cronobacter',
#  28141: 'Cronobacter sakazakii',
#  642: 'Aeromonas',
#  22: 'Shewanella',
#  654: 'Aeromonas veronii',
#  51668: 'Tetragenococcus',
#  51669: 'Tetragenococcus halophilus',
#  1105032: 'Streptococcus sp. BS35b',
#  1175452: 'Peptoniphilus rhinitidis',
#  84031: 'Clostridium sartagoforme',
#  52584: 'Brachyspira pilosicoli',
#  43668: 'Brachybacterium',
#  338: 'Xanthomonas',
#  53413: 'Xanthomonas axonopodis',
#  182639: 'Kribbella',
#  2000: 'Streptosporangium',
#  1871072: 'Nocardioidaceae bacterium',
#  460086: 'Kribbella catacumbae',
#  2001: 'Streptosporangium roseum',
#  210: 'Helicobacter pylori',
#  82202: 'Centipeda',
#  671224: 'Selenomonas artemidis',
#  157688: 'Leptotrichia hofstadii',
#  157691: 'Leptotrichia shahii',
#  157687: 'Leptotrichia wadei',
#  82203: 'Centipeda periodontii',
#  469593: 'Bacteroides sp. 3_1_40A',
#  644: 'Aeromonas hydrophila',
#  1851: 'Saccharomonospora',
#  81: 'Hyphomicrobium',
#  1513: 'Clostridium tetani',
#  665874: 'Limnohabitans',
#  52972: 'Polaromonas',
#  884684: 'Mageeibacillus indolicus',
#  48296: 'Acinetobacter pittii',
#  106648: 'Acinetobacter bereziniae',
#  157268: 'Helicobacter winghamensis',
#  1169673: 'Streptococcus sp. GMD4S',
#  46254: 'Oenococcus',
#  1247: 'Oenococcus oeni',
#  67575: 'Rheinheimera',
#  417127: 'Zunongwangia',
#  29494: 'Vibrio furnissii',
#  398743: 'Zunongwangia profunda',
#  1169674: 'Streptococcus sp. GMD5S',
#  1549: 'Faecalispora sporosphaeroides',
#  413503: 'Cronobacter malonaticus',
#  213: 'Helicobacter cinaedi',
#  313439: 'Streptococcus massiliensis',
#  179628: 'Clostridium colicanis',
#  419005: 'Prevotella amnii',
#  470: 'Acinetobacter baumannii',
#  587: 'Providencia rettgeri',
#  1111454: 'Megasphaera vaginalis (ex Srinivasan et al. 2021)',
#  651: 'Aeromonas media',
#  196024: 'Aeromonas dhakensis',
#  1269: 'Micrococcus',
#  1270: 'Micrococcus luteus',
#  62322: 'Shewanella baltica',
#  357: 'Agrobacterium',
#  379: 'Rhizobium',
#  1375: 'Aerococcus',
#  303: 'Pseudomonas putida',
#  136996: 'Bradyrhizobium lupini',
#  614: 'Serratia liquefaciens',
#  358: 'Agrobacterium tumefaciens',
#  1377: 'Aerococcus viridans',
#  57495: 'Dermacoccus',
#  2053: 'Gordonia',
#  125216: 'Roseomonas',
#  1651: 'Alloiococcus',
#  144193: 'Turicella',
#  188626: 'Dermacoccus sp. Ellin185',
#  249058: 'Gordonia otitidis',
#  38288: 'Corynebacterium genitalium',
#  425941: 'Hoylesella nanceiensis',
#  1652: 'Alloiococcus otitis',
#  29321: 'Corynebacterium otitidis',
#  36820: 'Gordonia aichiensis',
#  505: 'Kingella oralis',
#  334542: 'Rhodococcus qingshengii',
#  84595: 'Gordonia polyisoprenivorans',
#  170573: 'Staphylococcus pettenkoferi',
#  177971: 'Shuttleworthella',
#  712213: 'Capnocytophaga sp. oral taxon 332',
#  28133: 'Prevotella nigrescens',
#  936381: 'Selenomonas sp. CM52',
#  712469: 'Alloprevotella sp. oral taxon 473',
#  189722: 'Hoylesella marshii',
#  665939: 'Campylobacter sp. 10_1_50',
#  52227: 'Prevotella dentalis',
#  69710: 'Treponema vincentii',
#  305719: 'Segatella baroniae',
#  28137: 'Prevotella veroralis',
#  177972: 'Shuttleworthella satelles',
#  135080: 'Selenomonas flueggei',
#  434: 'Acetobacter',
#  1847: 'Pseudonocardia',
#  43770: 'Corynebacterium striatum',
#  37914: 'Dietzia',
#  59195: 'Rickettsiella',
#  321318: 'Dietzia cinnamea',
#  39791: 'Corynebacterium glucuronolyticum',
#  219301: 'Brachybacterium muris',
#  82347: 'Facklamia languida',
#  59196: 'Rickettsiella grylli',
#  173362: 'Brachybacterium paraconglomeratum',
#  2747: 'Carnobacterium',
#  2751: 'Carnobacterium maltaromaticum',
#  2054: 'Gordonia bronchialis',
#  305976: 'Pusillimonas',
#  33986: 'Exiguobacterium',
#  59735: 'Bergeyella',
#  1203566: 'Corynebacterium sp. KPL1859',
#  1078083: 'Staphylococcus sp. HGB0015',
#  1329: 'Streptococcus canis',
#  1015: 'Bergeyella zoohelcum',
#  53363: 'Brevibacterium mcbrellneri',
#  53457: 'Janibacter',
#  364298: 'Janibacter hoylei',
#  712438: 'Porphyromonas sp. oral taxon 279',
#  47229: 'Massilia timonae',
#  31983: 'Helcococcus',
#  1286: 'Staphylococcus simulans',
#  441501: 'Corynebacterium massiliense',
#  40091: 'Helcococcus kunzii',
#  1835: 'Saccharopolyspora',
#  33882: 'Microbacterium',
#  36807: 'Microbacterium laevaniformans',
#  47886: 'Pseudomonas luteola',
#  258224: 'Corynebacterium resistens',
#  317: 'Pseudomonas syringae',
#  85698: 'Achromobacter xylosoxidans',
#  28115: 'Porphyromonas macacae',
#  28189: 'Capnocytophaga cynodegmi',
#  598660: 'Corynebacterium pyruviciproducens',
#  486: 'Neisseria lactamica',
#  111105: 'Porphyromonas gulae',
#  161889: 'Corynebacterium lipophiloflavum',
#  1060: 'Rhodobacter',
#  1063: 'Cereibacter sphaeroides',
#  68909: 'Deinococcus geothermalis',
#  175628: 'Gordonia paraffinivorans',
#  185294: 'Segatella paludivivens',
#  57499: 'Kytococcus',
#  528: 'Ochrobactrum',
#  1276: 'Kytococcus sedentarius',
#  101564: 'Ectopseudomonas alcaliphila',
#  529: 'Brucella anthropi',
#  497: 'Psychrobacter',
#  330922: 'Psychrobacter cryohalolentis',
#  137730: 'Falseniella ignava',
#  44471: 'Microcoleus',
#  1203573: 'Propionibacterium sp. KPL1844',
#  89966: 'Hymenobacter',
#  282402: 'Prevotella multiformis',
#  90243: 'Oligella',
#  1013: 'Weeksella',
#  428711: 'Jonquetella',
#  90245: 'Oligella urethralis',
#  1014: 'Weeksella virosa',
#  1078764: 'Corynebacterium sp. HFH0082',
#  576927: 'Brevibacterium massiliense',
#  ...}
